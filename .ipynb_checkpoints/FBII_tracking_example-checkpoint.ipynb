# %%
import PyHEADTAIL
from PyHEADTAIL.particles import generators
from PyHEADTAIL.general.printers import SilentPrinter
from PyHEADTAIL.trackers.longitudinal_tracking import RFSystems
from PyHEADTAIL.trackers.transverse_tracking import TransverseMap
from PyHEADTAIL.monitors.monitors import BunchMonitor, ParticleMonitor
from SOLEILII_parameters.SOLEILII_CDR_parameters import *
from PyHEADTAIL.particles import particles
from aps_figures.aps_one_column import *
from scipy.constants import m_p
from matplotlib import pyplot as plt
import seaborn as sbs
import numpy as np
N_MACROPARTICLES = int(1e3)
N_TURNS = int(200)
H_RF = 416
N_SEGMENTS = int(25)
np.random.seed(42)
PHI_RF = np.arccos(U_LOSS/V_RF) if (GAMMA**-2-GAMMA_T**-2) < 0 else pi+np.arccos(U_LOSS/V_RF)
PHI_RF = 0
long_map = RFSystems(
    CIRCUMFERENCE,
    [H_RF],
    [V_RF],
    [PHI_RF],
    [ALPHA_0],
    GAMMA,
    mass=m_e,
    charge=e
    )

# %%
n_gaps = 50
np.random.seed(42)
#Preparing custom electron bunch train
x_array = np.zeros(shape=(H_RF,))
xp_array = np.zeros(shape=(H_RF,))
y_array = np.zeros(shape=(H_RF,))
yp_array = np.zeros(shape=(H_RF,))
dp_array = np.zeros(shape=(H_RF,))
z_array = np.linspace(0, CIRCUMFERENCE-CIRCUMFERENCE/H_RF, H_RF)

electron_bunch_list = []
monitor_list = []
r_x = 2*np.sqrt(EPSILON_X*BETA_X_SMOOTH)
r_xp = 2*np.sqrt(EPSILON_X*BETA_X_SMOOTH)
r_y = 2*np.sqrt(EPSILON_Y*BETA_Y_SMOOTH)
r_yp = 2*np.sqrt(EPSILON_Y*BETA_Y_SMOOTH)  
for ind, h in enumerate(range(H_RF)):
    np.random.seed(42)
    electron_bunch = generators.ParticleGenerator(macroparticlenumber=N_MACROPARTICLES//2,
                                                  intensity=INTENSITY_PER_BUNCH//2,
                                                  charge=e, gamma=GAMMA, mass=m_e,
                                                  circumference=CIRCUMFERENCE,
                                                  # distribution_x=generators.kv2D(r_x, r_xp),
                                                  distribution_x = generators.gaussian2D(EPSILON_X),
                                                  alpha_x=ALPHA_X_SMOOTH, beta_x=BETA_X_SMOOTH,
                                                  # distribution_y=generators.kv2D(r_y, r_yp),
                                                  distribution_y = generators.gaussian2D(EPSILON_Y),
                                                  alpha_y=ALPHA_Y_SMOOTH, beta_y=BETA_Y_SMOOTH,
                                                  distribution_z=generators.gaussian2D_asymmetrical(SIGMA_Z, SIGMA_DP),
                                                  printer=SilentPrinter()
                                 ).generate()
#     electron_bunch_twin = particles.Particles(macroparticlenumber=N_MACROPARTICLES//2,
#                                                   particlenumber_per_mp=INTENSITY_PER_BUNCH/N_MACROPARTICLES,
#                                                   charge=e, gamma=GAMMA, mass=m_e,
#                                                   circumference=CIRCUMFERENCE,
#                                                   coords_n_momenta_dict={
#                                                     'x': -electron_bunch.x,
#                                                     'xp': -electron_bunch.xp,
#                                                     'y': -electron_bunch.y,
#                                                     'yp': -electron_bunch.yp,
#                                                     'z': -electron_bunch.z,
#                                                     'dp': -electron_bunch.dp
#                                                   },
#                                                   printer=SilentPrinter()
#                                      )

#     electron_bunch += electron_bunch_twin
    np.random.seed(ind)
    # electron_bunch.y += np.random.normal(scale=0.02*electron_bunch.sigma_y(), size=1)
    electron_bunch.y -= electron_bunch.mean_y()
    filename = 'Results/BM_n={0:}'.format(int(h))
    bunch_monitor = BunchMonitor(filename, n_steps=N_SEGMENTS*N_TURNS, parameters_dict=None)
    electron_bunch.z += h*CIRCUMFERENCE/H_RF
    electron_bunch_list.append(electron_bunch)
    monitor_list.append(bunch_monitor)
for i in range(n_gaps):
    electron_bunch_list[-i].intensity = 0
    # electron_bunch_list[104+i].intensity = 0
    # electron_bunch_list[208+i].intensity = 0
    # electron_bunch_list[312+i].intensity = 0
print(electron_bunch_list[0].sigma_x())
# Out:
# 1.6874703133163647e-05

# %%
s = np.arange(0, N_SEGMENTS + 1) * CIRCUMFERENCE / N_SEGMENTS
alpha_x, alpha_y = ALPHA_X_SMOOTH * \
    np.ones(N_SEGMENTS), ALPHA_Y_SMOOTH * np.ones(N_SEGMENTS)
beta_x, beta_y = BETA_X_SMOOTH * \
    np.ones(N_SEGMENTS), BETA_Y_SMOOTH * np.ones(N_SEGMENTS)
D_x, D_y = np.zeros(N_SEGMENTS),  np.zeros(N_SEGMENTS)
trans_map = TransverseMap(s, alpha_x, beta_x, D_x,
                              alpha_y, beta_y, D_y, Q_X, Q_Y)

# %%
from PyHEADTAIL.ion_cloud.ion_cloud import BeamIonElement
from tqdm.notebook import tqdm
trans_one_turn = [m for m in trans_map]
BI = BeamIonElement()
beam_ion_elements = []
particle_monitor = True
set_aperture = True
n_macroparticles = int(2e5)
n_steps = int(H_RF*N_TURNS)
# for ind, m in enumerate(trans_one_turn):
#     if ind == 0:
#             beam_ion_elements.append(BeamIonElement(dist_ions='GS',
#                                                     monitor_name='Results/IPM(ind={0:})'.format(int(ind)),
#                                                     use_particle_monitor=particle_monitor,
#                                                     set_aperture=set_aperture,
#                                                     n_macroparticles_max=n_macroparticles,
#                                                     n_steps=n_steps,
#                                                     n_segments=N_SEGMENTS,
#                                                     ring_circumference=CIRCUMFERENCE,
#                                                     interaction_model='weak-weak'))
#     beam_ion_elements.append(BeamIonElement(dist_ions='GS',
#                                             monitor_name='Results/IM(ind={0:})'.format(int(ind)),
#                                             set_aperture=set_aperture,
#                                             n_macroparticles_max=n_macroparticles,
#                                             n_steps=n_steps,
#                                             n_segments=N_SEGMENTS,
#                                             ring_circumference=CIRCUMFERENCE,
#                                             interaction_model='weak-weak'))
trans_one_turn = [item for sublist in zip(trans_one_turn, beam_ion_elements) for item in sublist]
print('First 5 elements of a transverse map: ')
for item in trans_one_turn[:5]:
    print(item)
# for turn in tqdm(range(N_TURNS)):
#     for index, m_ in enumerate((trans_one_turn)):
#         for bunch_index, electron_bunch in enumerate(electron_bunch_list):
#             m_.track(electron_bunch_list[bunch_index])    
#             long_map.track(electron_bunch_list[bunch_index])
#             if index % 2 == 0:
#                 monitor_list[bunch_index].dump(electron_bunch_list[bunch_index])
#             if electron_bunch_list[bunch_index].intensity < 1e3 and (index+1) % 2 == 0:
#                 m_.clear_ions()
# Out:
# First 5 elements of a transverse map:

# %%
from PyHEADTAIL.ion_cloud.ion_cloud import BeamIonElement
BI = BeamIonElement(dist_ions='GS',
                    monitor_name=None,
                    set_aperture=set_aperture,
                    n_macroparticles_max=int(1e4),
                    n_steps=n_steps,
                    n_segments=N_SEGMENTS,
                    ring_circumference=CIRCUMFERENCE,
                    interaction_model='weak-weak')

# %%
electron_bunch = generators.ParticleGenerator(macroparticlenumber=int(1e3),
                                              intensity=INTENSITY_PER_BUNCH,
                                              charge=e, gamma=GAMMA, mass=m_e,
                                              circumference=CIRCUMFERENCE,
                                              # distribution_x=generators.kv2D(r_x, r_xp),
                                              distribution_x = generators.gaussian2D(EPSILON_X),
                                              alpha_x=ALPHA_X_SMOOTH, beta_x=BETA_X_SMOOTH,
                                              # distribution_y=generators.kv2D(r_y, r_yp),
                                              distribution_y = generators.gaussian2D(EPSILON_Y),
                                              alpha_y=ALPHA_Y_SMOOTH, beta_y=BETA_Y_SMOOTH,
                                              distribution_z=generators.gaussian2D_asymmetrical(SIGMA_Z, SIGMA_DP),
                                              printer=SilentPrinter()
                             ).generate()

# %%
# %%prun
BI.track(electron_bunch)
# Out:
#          855 function calls (842 primitive calls) in 0.330 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         6    0.089    0.015    0.089    0.015 {method 'put' of 'numpy.ndarray' objects}
#        10    0.089    0.009    0.089    0.009 {built-in method PyHEADTAIL.cobra_functions.stats.std}
#        10    0.081    0.008    0.081    0.008 {method 'take' of 'numpy.ndarray' objects}
#        18    0.040    0.002    0.040    0.002 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.025    0.025    0.329    0.329 ion_cloud.py:256(track)
#        44    0.001    0.000    0.001    0.000 {method 'copy' of 'numpy.ndarray' objects}
#         1    0.001    0.001    0.330    0.330 <string>:1(<module>)
#         4    0.001    0.000    0.001    0.000 pmath.py:50(_wofz)
#         1    0.000    0.000    0.001    0.001 aperture.py:229(tag_lost_ellipse)
#         5    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#         4    0.000    0.000    0.033    0.008 particles.py:331(sigma_x)
#         1    0.000    0.000    0.012    0.012 particles.py:342(sigma_xp)
#         4    0.000    0.000    0.033    0.008 particles.py:334(sigma_y)
#         2    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.083    0.083 ion_cloud.py:154(_generate_ions)
#     55/42    0.000    0.000    0.211    0.005 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         8    0.000    0.000    0.040    0.005 _methods.py:162(_mean)
#         4    0.000    0.000    0.000    0.000 {method 'normal' of 'numpy.random.mtrand.RandomState' objects}
#         8    0.000    0.000    0.000    0.000 _methods.py:66(_count_reduce_items)
#        16    0.000    0.000    0.001    0.000 particles.py:220(update)
#         2    0.000    0.000    0.001    0.000 ion_cloud.py:324(get_efieldn)
#         1    0.000    0.000    0.000    0.000 function_base.py:23(linspace)
#         2    0.000    0.000    0.001    0.001 particles.py:267(__add__)
#         8    0.000    0.000    0.040    0.005 fromnumeric.py:3322(mean)
#         2    0.000    0.000    0.001    0.000 efields_funcs.py:23(_efieldn_mit)
#         2    0.000    0.000    0.050    0.025 ion_cloud.py:221(_get_efields)
#        10    0.000    0.000    0.000    0.000 fromnumeric.py:69(_wrapreduction)
#         6    0.000    0.000    0.000    0.000 element.py:32(__new__)
#         2    0.000    0.000    0.000    0.000 generators.py:130(_transverse_linear_matcher)
#         2    0.000    0.000    0.000    0.000 numeric.py:2257(isclose)
#         4    0.000    0.000    0.000    0.000 particles.py:80(gamma)
#         2    0.000    0.000    0.000    0.000 generators.py:106(transverse_linear_matcher)
#         1    0.000    0.000    0.330    0.330 {built-in method builtins.exec}
#         2    0.000    0.000    0.000    0.000 numeric.py:2337(within_tol)
#         1    0.000    0.000    0.000    0.000 ion_cloud.py:210(track_ions_in_drift)
#         1    0.000    0.000    0.010    0.010 particles.py:346(sigma_yp)
#        10    0.000    0.000    0.081    0.008 fromnumeric.py:51(_wrapfunc)
#        10    0.000    0.000    0.081    0.008 fromnumeric.py:93(take)
#         2    0.000    0.000    0.001    0.000 efields_funcs.py:253(efieldn_checked)
#         4    0.000    0.000    0.000    0.000 particles.py:24(__init__)
#         6    0.000    0.000    0.089    0.015 fromnumeric.py:486(put)
#        10    0.000    0.000    0.081    0.008 <__array_function__ internals>:2(take)
#         4    0.000    0.000    0.020    0.005 particles.py:315(mean_y)
#         8    0.000    0.000    0.041    0.005 <__array_function__ internals>:2(mean)
#         9    0.000    0.000    0.000    0.000 fromnumeric.py:2367(all)
#        12    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(concatenate)
#         4    0.000    0.000    0.000    0.000 _ufunc_config.py:32(seterr)
#        47    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        16    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#         1    0.000    0.000    0.000    0.000 generators.py:377(_create_phase_space)
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        16    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         4    0.000    0.000    0.020    0.005 particles.py:307(mean_x)
#        40    0.000    0.000    0.000    0.000 particles.py:226(<genexpr>)
#         4    0.000    0.000    0.000    0.000 _ufunc_config.py:131(geterr)
#         3    0.000    0.000    0.000    0.000 particles.py:63(intensity)
#         9    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(all)
#         6    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.generic' objects}
#         2    0.000    0.000    0.000    0.000 efields_funcs.py:19(_sig_sqrt)
#         6    0.000    0.000    0.089    0.015 <__array_function__ internals>:2(put)
#         1    0.000    0.000    0.000    0.000 {method 'uniform' of 'numpy.random.mtrand.RandomState' objects}
#         1    0.000    0.000    0.000    0.000 generators.py:355(generate)
#         1    0.000    0.000    0.000    0.000 generators.py:466(_uniform2D)
#         4    0.000    0.000    0.000    0.000 particles.py:119(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 aperture.py:22(make_int32)
#        16    0.000    0.000    0.000    0.000 {method 'update' of 'set' objects}
#        28    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#         2    0.000    0.000    0.000    0.000 generators.py:455(_gaussian2D)
#         2    0.000    0.000    0.000    0.000 numeric.py:2179(allclose)
#        10    0.000    0.000    0.000    0.000 fromnumeric.py:70(<dictcomp>)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(result_type)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(linspace)
#         1    0.000    0.000    0.001    0.001 aperture.py:33(track)
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         1    0.000    0.000    0.000    0.000 aperture.py:190(__init__)
#         8    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(allclose)
#        19    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#        26    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#         1    0.000    0.000    0.000    0.000 generators.py:304(__init__)
#         4    0.000    0.000    0.000    0.000 particles.py:115(get_coords_n_momenta_dict)
#         1    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.generic' objects}
#         2    0.000    0.000    0.000    0.000 _ufunc_config.py:425(__init__)
#        10    0.000    0.000    0.000    0.000 fromnumeric.py:89(_take_dispatcher)
#        30    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.001    0.001 slicing.py:50(cleaned_long_track_method)
#         2    0.000    0.000    0.000    0.000 _ufunc_config.py:429(__enter__)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2268(any)
#        16    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         8    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#         6    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x738200}
#         6    0.000    0.000    0.000    0.000 _methods.py:60(_all)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(isclose)
#        18    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         6    0.000    0.000    0.000    0.000 fromnumeric.py:482(_put_dispatcher)
#        12    0.000    0.000    0.000    0.000 multiarray.py:148(concatenate)
#         1    0.000    0.000    0.000    0.000 numeric.py:1858(isscalar)
#         2    0.000    0.000    0.000    0.000 _ufunc_config.py:434(__exit__)
#         1    0.000    0.000    0.001    0.001 aperture.py:196(tag_lost_particles)
#         2    0.000    0.000    0.000    0.000 generators.py:446(gaussian2D_asymmetrical)
#         8    0.000    0.000    0.000    0.000 fromnumeric.py:3317(_mean_dispatcher)
#         1    0.000    0.000    0.000    0.000 generators.py:397(_linear_match_phase_space)
#        12    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         9    0.000    0.000    0.000    0.000 fromnumeric.py:2362(_all_dispatcher)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(any)
#         3    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         6    0.000    0.000    0.000    0.000 {method 'copy' of 'list' objects}
#        10    0.000    0.000    0.000    0.000 particles.py:77(gamma)
#         1    0.000    0.000    0.000    0.000 numerictypes.py:358(issubdtype)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(ndim)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:3127(ndim)
#         6    0.000    0.000    0.000    0.000 {built-in method numpy.ascontiguousarray}
#         2    0.000    0.000    0.000    0.000 numerictypes.py:284(issubclass_)
#         1    0.000    0.000    0.000    0.000 _methods.py:54(_any)
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:3123(_ndim_dispatcher)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         3    0.000    0.000    0.000    0.000 multiarray.py:664(result_type)
#         4    0.000    0.000    0.000    0.000 particles.py:94(betagamma)
#         1    0.000    0.000    0.000    0.000 particles.py:213(clean_slices)
#         1    0.000    0.000    0.000    0.000 generators.py:462(uniform2D)
#         2    0.000    0.000    0.000    0.000 numeric.py:2175(_allclose_dispatcher)
#         1    0.000    0.000    0.000    0.000 function_base.py:18(_linspace_dispatcher)
#         1    0.000    0.000    0.000    0.000 element.py:29(__init__)
#         1    0.000    0.000    0.000    0.000 particles.py:101(p0)
#         2    0.000    0.000    0.000    0.000 numeric.py:2253(_isclose_dispatcher)
#         1    0.000    0.000    0.000    0.000 particles.py:87(beta)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2263(_any_dispatcher)

# %%
from PyHEADTAIL.impedances.wakes import CircularResistiveWall, WakeField
from PyHEADTAIL.particles import slicing

n_wake_slices = 500                                                         ### Number of slices for the wakefield interaction
z_cuts = (-4*electron_bunch.sigma_z(), 4*electron_bunch.sigma_z())          ### Range of the slices
print('Wake slicer range: ({0:.3f}, {1:.3f})'.format(z_cuts[0], z_cuts[1]))
wake_slicer = slicing.UniformBinSlicer(                                     ### Slicer used to separate particles based on their longitudinal positions
    n_slices=n_wake_slices, z_cuts=z_cuts)
length = 1 # Beam pipe length in [m].
rho = 1e-6 # Resistivity in [ohm.m].
radius = 10e-3 # Beam pipe radius in [m].
dt_min = CIRCUMFERENCE/c/n_wake_slices                                                  ### Minimal time step
res_wall = CircularResistiveWall(pipe_radius=radius,                        ### Radius of the accelerator pipe
                                  resistive_wall_length=length,                ### Length of the accelerator pipe
                                  dt_min=dt_min,                            ### Timestep
                                  conductivity=1/rho)                       ### Conductivity of the accelerator pipe 

wake_field = WakeField(wake_slicer, res_wall)
# Out:
# Wake slicer range: (-0.011, 0.011)

# %%
# %%prun
wake_field.track(electron_bunch)
# Out:
#          209 function calls in 0.639 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.153    0.153    0.211    0.211 wake_kicks.py:209(apply)
#         1    0.142    0.142    0.208    0.208 wake_kicks.py:246(apply)
#         2    0.122    0.061    0.122    0.061 {method 'take' of 'numpy.ndarray' objects}
#         1    0.086    0.086    0.112    0.112 slicing.py:599(compute_sliceset_kwargs)
#         2    0.048    0.024    0.048    0.024 {method 'astype' of 'numpy.ndarray' objects}
#         2    0.033    0.017    0.033    0.017 {built-in method PyHEADTAIL.cobra_functions.stats.mean_per_slice}
#        11    0.026    0.002    0.149    0.014 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         1    0.015    0.015    0.063    0.063 pmath.py:216(<lambda>)
#         1    0.012    0.012    0.012    0.012 {built-in method PyHEADTAIL.cobra_functions.stats.count_macroparticles_per_slice}
#         2    0.001    0.001    0.001    0.001 {built-in method numpy.core._multiarray_umath.correlate}
#         1    0.000    0.000    0.639    0.639 wakes.py:121(track)
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#         2    0.000    0.000    0.000    0.000 wakes.py:612(wake)
#         2    0.000    0.000    0.002    0.001 wake_kicks.py:118(_accumulate_source_signal)
#         2    0.000    0.000    0.108    0.054 pmath.py:109(_mean_per_slice_cpu)
#         2    0.000    0.000    0.000    0.000 slicing.py:124(z_centers)
#         2    0.000    0.000    0.001    0.001 wake_kicks.py:87(_convolution_numpy)
#         2    0.000    0.000    0.000    0.000 wake_kicks.py:66(_wake_factor)
#         2    0.000    0.000    0.122    0.061 fromnumeric.py:51(_wrapfunc)
#         2    0.000    0.000    0.000    0.000 slicing.py:303(convert_to_time)
#         4    0.000    0.000    0.000    0.000 _methods.py:91(_clip_dep_is_scalar_nan)
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         2    0.000    0.000    0.122    0.061 fromnumeric.py:93(take)
#         1    0.000    0.000    0.220    0.220 slicing.py:348(slice)
#         1    0.000    0.000    0.639    0.639 {built-in method builtins.exec}
#         1    0.000    0.000    0.026    0.026 slicing.py:29(make_int32)
#         2    0.000    0.000    0.122    0.061 <__array_function__ internals>:2(take)
#         1    0.000    0.000    0.026    0.026 <__array_function__ internals>:2(where)
#         1    0.000    0.000    0.108    0.108 slicing.py:443(add_statistics)
#         2    0.000    0.000    0.000    0.000 {method 'clip' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.012    0.012 pmath.py:148(_count_macroparticles_per_slice_cpu)
#         2    0.000    0.000    0.001    0.001 numeric.py:748(convolve)
#         1    0.000    0.000    0.220    0.220 particles.py:121(get_slices)
#         1    0.000    0.000    0.000    0.000 element.py:32(__new__)
#         2    0.000    0.000    0.000    0.000 _methods.py:125(_clip)
#         4    0.000    0.000    0.012    0.003 slicing.py:152(n_macroparticles_per_slice)
#         4    0.000    0.000    0.000    0.000 fromnumeric.py:3127(ndim)
#         1    0.000    0.000    0.000    0.000 slicing.py:67(__init__)
#         5    0.000    0.000    0.063    0.013 slicing.py:168(particles_within_cuts)
#         1    0.000    0.000    0.000    0.000 wake_kicks.py:217(<listcomp>)
#         1    0.000    0.000    0.000    0.000 wake_kicks.py:254(<listcomp>)
#         1    0.000    0.000    0.000    0.000 slicing.py:384(extract_beam_parameters)
#         2    0.000    0.000    0.000    0.000 _methods.py:106(_clip_dep_invoke_with_casting)
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#        11    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#         2    0.000    0.000    0.108    0.054 slicing.py:522(_mean)
#         4    0.000    0.000    0.000    0.000 _methods.py:101(_clip_dep_is_byte_swapped)
#        15    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         2    0.000    0.000    0.000    0.000 slicing.py:186(particles_within_cuts_slice)
#         3    0.000    0.000    0.000    0.000 slicing.py:415(__hash__)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(concatenate)
#         1    0.000    0.000    0.016    0.016 slicing.py:478(_mean_y)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         2    0.000    0.000    0.001    0.001 <__array_function__ internals>:2(convolve)
#         1    0.000    0.000    0.000    0.000 wake_kicks.py:252(<listcomp>)
#         1    0.000    0.000    0.108    0.108 decorators.py:65(sync_after_wrap)
#         4    0.000    0.000    0.000    0.000 slicing.py:128(n_slices)
#         1    0.000    0.000    0.000    0.000 wake_kicks.py:215(<listcomp>)
#        11    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(ndim)
#         1    0.000    0.000    0.639    0.639 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 particles.py:70(charge_per_mp)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         1    0.000    0.000    0.012    0.012 pmath.py:224(<lambda>)
#         3    0.000    0.000    0.000    0.000 particles.py:77(gamma)
#         1    0.000    0.000    0.000    0.000 particles.py:63(intensity)
#         1    0.000    0.000    0.000    0.000 pmath.py:230(<lambda>)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         3    0.000    0.000    0.000    0.000 slicing.py:325(config)
#         1    0.000    0.000    0.091    0.091 slicing.py:472(_mean_x)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:89(_take_dispatcher)
#         3    0.000    0.000    0.000    0.000 particles.py:87(beta)
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#         1    0.000    0.000    0.000    0.000 multiarray.py:341(where)
#         1    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x738200}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         4    0.000    0.000    0.000    0.000 fromnumeric.py:3123(_ndim_dispatcher)
#         2    0.000    0.000    0.000    0.000 {method 'appendleft' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 multiarray.py:148(concatenate)
#         1    0.000    0.000    0.000    0.000 wake_kicks.py:253(<listcomp>)
#         1    0.000    0.000    0.000    0.000 wake_kicks.py:216(<listcomp>)
#         2    0.000    0.000    0.000    0.000 numeric.py:744(_convolve_dispatcher)
#         1    0.000    0.000    0.000    0.000 slicing.py:395(get_long_cuts)
#         2    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 particles.py:101(p0)

# %%
# %%timeit 
electron_bunch.x
# Out:
# 32.6 ns ± 1.54 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
electron_bunch.x.shape
# Out:
# (10000000,)

# %%
fig, axlist = plt.subplots(1, 2)
axlist[0].scatter(electron_bunch_list[400].x/electron_bunch_list[400].sigma_x(), electron_bunch_list[400].xp/electron_bunch_list[400].sigma_xp(), alpha=0.5) 
# axlist[0].axvline(2*electron_bunch.sigma_x())
# axlist[0].axvline(electron_bunch.sigma_x())
axlist[0].set_ylim(-3.5, 3.5)
print('{:.2e}'.format(electron_bunch_list[0].sigma_y()))
axlist[1].hist(electron_bunch_list[0].y/electron_bunch_list[0].sigma_y(), bins=25)
for ax in axlist:
    ax.set_xlim(-3.5, 3.5)
# Out:
# 1.46e-05

# %%
ion_cloud = trans_one_turn[1].get_ion_beam()
fig, ax = plt.subplots(1, 1)
ax = sbs.jointplot(ion_cloud.y/electron_bunch.sigma_y(), ion_cloud.yp, marker='.', alpha=0.05)
ax.ax_joint.set_xlabel('$y$')
ax.ax_joint.set_ylabel('$p_y$')
ax.ax_joint.set_xlabel('$y_\mathrm{ion}/\sigma_e$')
ax.ax_joint.set_ylim(-10*ion_cloud.sigma_yp(), 10*ion_cloud.sigma_yp())
print('Ion cloud intensity {:.1e}'.format(ion_cloud.intensity))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_13891/2347278454.py in <module>
# ----> 1 ion_cloud = trans_one_turn[1].get_ion_beam()
#       2 fig, ax = plt.subplots(1, 1)
#       3 ax = sbs.jointplot(ion_cloud.y/electron_bunch.sigma_y(), ion_cloud.yp, marker='.', alpha=0.05)
#       4 ax.ax_joint.set_xlabel('$y$')
#       5 ax.ax_joint.set_ylabel('$p_y$')
#
# IndexError: list index out of range

# %%
from scipy.special import k0
fig, ax  = plt.subplots(1, 1)
ion_cloud = trans_one_turn[1].get_ion_beam()
ax = sbs.kdeplot(ion_cloud.y/ion_cloud.sigma_y())
sig = .75
x = np.linspace(-6, 6)
y = 1/np.sqrt(2*pi*sig**2)*np.exp(-x**2/2/sig**2)
ax.plot(x, y)
# r = np.linspace(min(ion_cloud.y), max(ion_cloud.y), 100)
# # ax.plot(r, get_n_i(r, 2*ion_cloud.sigma_y())/2.5e6)
# x = np.linspace(min(ion_cloud.y), max(ion_cloud.y), 100)
# # ax.plot(x, get_dist(x, electron_bunch.sigma_y()))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_13891/3308250500.py in <module>
#       1 from scipy.special import k0
#       2 fig, ax  = plt.subplots(1, 1)
# ----> 3 ion_cloud = trans_one_turn[1].get_ion_beam()
#       4 ax = sbs.kdeplot(ion_cloud.y/ion_cloud.sigma_y())
#       5 sig = .75
#
# IndexError: list index out of range

# %%
from mbtrack2.instability.ions
s = np.load('lattice_functions/s.npy')
beta_x = np.load('lattice_functions/beta_x.npy')
beta_y = np.load('lattice_functions/beta_y.npy')
lim = s.shape[0]//4
plt.plot(s[:lim], beta_x[:lim])
plt.plot(s[:lim], beta_y[:lim])
plt.xlim(0, 20)
plt.ylim(0, )
# Out:
# (0.0, 23.14087109613333)

# %%
n_segments = 100  # Adjust this value as needed
data_files = ['s', 'beta_x', 'beta_y', 'alpha_x', 'alpha_y', 'eta_x', 'eta_y']
data = {}

for file in data_files:
    data[file] = np.load('lattice_functions/' + file + '.npy')


s = data['s'][::len(data['s']) // n_segments]
beta_x = data['beta_x'][::len(data['beta_x']) // n_segments]
beta_y = data['beta_y'][::len(data['beta_y']) // n_segments]
alpha_x = data['alpha_x'][::len(data['alpha_x']) // n_segments]
alpha_y = data['alpha_y'][::len(data['alpha_y']) // n_segments]
eta_x = data['eta_x'][::len(data['eta_x']) // n_segments]
eta_y = data['eta_y'][::len(data['eta_y']) // n_segments]

D_x, D_y = np.array(eta_x), np.array(eta_y)
alpha_x, alpha_y = np.array(alpha_x), np.array(alpha_y)
beta_x, beta_y = np.array(beta_x), np.array(beta_y)

# %%
plt.hist(data['beta_x'], density=True, bins=16)
plt.hist(beta_x, density=True, bins=16, alpha=0.6)
# Out:
# (array([0.13033225, 0.23058783, 0.14035781, 0.16040892, 0.1904856 ,
#         0.02005112, 0.04010223, 0.04010223, 0.01002556, 0.        ,
#         0.        , 0.        , 0.04010223, 0.01002556, 0.        ,
#         0.01002556]),
#  array([ 0.13777463,  1.11566752,  2.0935604 ,  3.07145329,  4.04934618,
#          5.02723906,  6.00513195,  6.98302484,  7.96091772,  8.93881061,
#          9.9167035 , 10.89459638, 11.87248927, 12.85038216, 13.82827505,
#         14.80616793, 15.78406082]),
#  <BarContainer object of 16 artists>)
